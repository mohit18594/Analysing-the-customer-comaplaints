# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("customer_complaints.csv")

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data.head()
# Out:
#   Complaint ID   Customer Name Product/Service Complaint Type  \
# 0      CMP1000         Ann Cox          Retail  Billing Issue
# 1      CMP1001    Calvin Bowen         Telecom   Poor Service
# 2      CMP1002      Jared Reed          Retail   Poor Service
# 3      CMP1003     Hunter King         Banking  Wrong Product
# 4      CMP1004  Deborah Martin         Banking   Poor Service
#
#                                Complaint Description Date Received  \
# 0  Test top kitchen sit share heart time do natio...    2024-01-01
# 1  Company just newspaper structure stand much li...    2024-01-02
# 2  Should than coach message feel person cultural...    2024-01-03
# 3  Around pressure health play yard they federal ...    2024-01-04
# 4          College instead capital return know four.    2024-01-05
#
#   Complaint Status  Resolution Time (Days)
# 0          Pending                     NaN
# 1         Resolved                    21.0
# 2         Resolved                    11.0
# ...

# %%
data.head(5), data.tail(5)
# Out:
# (  Complaint ID   Customer Name Product/Service Complaint Type  \
#  0      CMP1000         Ann Cox          Retail  Billing Issue
#  1      CMP1001    Calvin Bowen         Telecom   Poor Service
#  2      CMP1002      Jared Reed          Retail   Poor Service
#  3      CMP1003     Hunter King         Banking  Wrong Product
#  4      CMP1004  Deborah Martin         Banking   Poor Service
#
#                                 Complaint Description Date Received  \
#  0  Test top kitchen sit share heart time do natio...    2024-01-01
#  1  Company just newspaper structure stand much li...    2024-01-02
#  2  Should than coach message feel person cultural...    2024-01-03
#  3  Around pressure health play yard they federal ...    2024-01-04
#  4          College instead capital return know four.    2024-01-05
#
#    Complaint Status  Resolution Time (Days)
#  0          Pending                     NaN
#  1         Resolved                    21.0
# ...

# %%
data_shape = data.shape
data_shape
# Out:
# (100, 8)

# %%
data_dtypes = data.dtypes
data_dtypes
# Out:
# Complaint ID               object
# Customer Name              object
# Product/Service            object
# Complaint Type             object
# Complaint Description      object
# Date Received              object
# Complaint Status           object
# Resolution Time (Days)    float64
# dtype: object

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# Complaint ID               0
# Customer Name              0
# Product/Service            0
# Complaint Type             0
# Complaint Description      0
# Date Received              0
# Complaint Status           0
# Resolution Time (Days)    22
# dtype: int64

# %%
data.describe()
# Out:
#        Resolution Time (Days)
# count               78.000000
# mean                14.384615
# std                  8.647845
# min                  1.000000
# 25%                  7.000000
# 50%                 13.500000
# 75%                 21.750000
# max                 30.000000

# %%
duplicate_rows = data.duplicated().sum()

# %%
# Check for duplicate rows
duplicate_rows = data.duplicated().sum()

# Remove duplicate rows if any exist
data_cleaned = data.drop_duplicates()

# Display the number of duplicates found and the new shape of the dataset
duplicate_rows, data_cleaned.shape
# Out:
# (0, (100, 8))

# %%
# Get the number of unique values in each column
unique_values = data.nunique()
unique_values
# Out:
# Complaint ID              100
# Customer Name             100
# Product/Service             5
# Complaint Type              5
# Complaint Description     100
# Date Received             100
# Complaint Status            3
# Resolution Time (Days)     27
# dtype: int64

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data.dropna(inplace=True)

# %%
data.replace("NA", np.nan, inplace=True)

# %%
data.drop(columns=['Complaint Type'], inplace=True)

# %%
data.rename(columns={'Customer Name': 'cus name'}, inplace=True)

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data.rename(columns={'Resolution Time(Days)': 'Time'}, inplace=True)

# %%
data
# Out:
#    Complaint ID        cus name Product/Service  \
# 1       CMP1001    Calvin Bowen         Telecom
# 2       CMP1002      Jared Reed          Retail
# 3       CMP1003     Hunter King         Banking
# 4       CMP1004  Deborah Martin         Banking
# 5       CMP1005    Jacob Turner      E-commerce
# ..          ...             ...             ...
# 92      CMP1092   Tara Reed DVM          Retail
# 93      CMP1093  Natasha Cooper         Banking
# 95      CMP1095   Blake Bennett      E-commerce
# 97      CMP1097   David Burgess      E-commerce
# 99      CMP1099   Joseph Morgan       Insurance
#
#                                 Complaint Description Date Received  \
# 1   Company just newspaper structure stand much li...    2024-01-02
# 2   Should than coach message feel person cultural...    2024-01-03
# 3   Around pressure health play yard they federal ...    2024-01-04
# 4           College instead capital return know four.    2024-01-05
# ...

# %%
filtered_data = data[data['Resolution Time (Days)'] > 30]
print("\nRows where Resolution Time (Days) is greater than 30:")
print(data)
# Out:
# Rows where Resolution Time (Days) is greater than 30:
#    Complaint ID        cus name Product/Service  \
# 1       CMP1001    Calvin Bowen         Telecom
# 2       CMP1002      Jared Reed          Retail
# 3       CMP1003     Hunter King         Banking
# 4       CMP1004  Deborah Martin         Banking
# 5       CMP1005    Jacob Turner      E-commerce
# ..          ...             ...             ...
# 92      CMP1092   Tara Reed DVM          Retail
# 93      CMP1093  Natasha Cooper         Banking
# 95      CMP1095   Blake Bennett      E-commerce
# 97      CMP1097   David Burgess      E-commerce
# 99      CMP1099   Joseph Morgan       Insurance
#
#                                 Complaint Description Date Received  \
# 1   Company just newspaper structure stand much li...    2024-01-02
# 2   Should than coach message feel person cultural...    2024-01-03
# 3   Around pressure health play yard they federal ...    2024-01-04
# ...

# %%
data = data.sort_values(by='cus name', ascending=True)
print("\nDataFrame sorted by cus name:")
print(data)
# Out:
# DataFrame sorted by cus name:
#    Complaint ID           cus name Product/Service  \
# 70      CMP1070         Alan Patel       Insurance
# 13      CMP1013      Amanda Walker         Telecom
# 18      CMP1018    Anthony Johnson         Telecom
# 51      CMP1051       Antonio Hill          Retail
# 95      CMP1095      Blake Bennett      E-commerce
# ..          ...                ...             ...
# 35      CMP1035     Tiffany Martin       Insurance
# 45      CMP1045  Timothy Singleton         Telecom
# 88      CMP1088   Timothy Thornton         Telecom
# 30      CMP1030       Trevor Moyer         Banking
# 84      CMP1084      Willie Powell         Telecom
#
#                                 Complaint Description Date Received  \
# 70  Career many deep everything new low through en...    2024-03-11
# 13  Go want official manage such small challenge t...    2024-01-14
# 18  Especially none energy agency hair same matter...    2024-01-19
# ...

# %%
data = data.sort_values(by='Complaint ID', ascending=False)
print("\nDataFrame sorted by Complaint ID	 (descending order):")
print(data)
# Out:
# DataFrame sorted by Complaint ID	 (descending order):
#    Complaint ID        cus name Product/Service  \
# 99      CMP1099   Joseph Morgan       Insurance
# 97      CMP1097   David Burgess      E-commerce
# 95      CMP1095   Blake Bennett      E-commerce
# 93      CMP1093  Natasha Cooper         Banking
# 92      CMP1092   Tara Reed DVM          Retail
# ..          ...             ...             ...
# 5       CMP1005    Jacob Turner      E-commerce
# 4       CMP1004  Deborah Martin         Banking
# 3       CMP1003     Hunter King         Banking
# 2       CMP1002      Jared Reed          Retail
# 1       CMP1001    Calvin Bowen         Telecom
#
#                                 Complaint Description Date Received  \
# 99     Agency listen size moment hour reveal concern.    2024-04-09
# 97  Begin live develop here security walk outside ...    2024-04-07
# 95  Around authority always tell one discuss deter...    2024-04-05
# ...

# %%
data = data.sort_values(by=['cus name', 'Date Received'], ascending=[True, True])
print("\nDataFrame sorted by cus name and then by Date Received:")
print(data)
# Out:
# DataFrame sorted by cus name and then by Date Received:
#    Complaint ID           cus name Product/Service  \
# 70      CMP1070         Alan Patel       Insurance
# 13      CMP1013      Amanda Walker         Telecom
# 18      CMP1018    Anthony Johnson         Telecom
# 51      CMP1051       Antonio Hill          Retail
# 95      CMP1095      Blake Bennett      E-commerce
# ..          ...                ...             ...
# 35      CMP1035     Tiffany Martin       Insurance
# 45      CMP1045  Timothy Singleton         Telecom
# 88      CMP1088   Timothy Thornton         Telecom
# 30      CMP1030       Trevor Moyer         Banking
# 84      CMP1084      Willie Powell         Telecom
#
#                                 Complaint Description Date Received  \
# 70  Career many deep everything new low through en...    2024-03-11
# 13  Go want official manage such small challenge t...    2024-01-14
# 18  Especially none energy agency hair same matter...    2024-01-19
# ...

# %%
data = data.sort_values(by='Date Received', ascending=True).head(3)
print("\nTop 3 rows sorted by Date Received:")
print(data)
# Out:
# Top 3 rows sorted by Date Received:
#   Complaint ID      cus name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description Date Received  \
# 1  Company just newspaper structure stand much li...    2024-01-02
# 2  Should than coach message feel person cultural...    2024-01-03
# 3  Around pressure health play yard they federal ...    2024-01-04
#
#   Complaint Status  Resolution Time (Days)
# 1         Resolved                    21.0
# 2         Resolved                    11.0
# 3          Pending                    14.0

# %%
data.rename(columns={'cus name': 'Location'}, inplace=True)

# %%
data
# Out:
#   Complaint ID      Location Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description Date Received  \
# 1  Company just newspaper structure stand much li...    2024-01-02
# 2  Should than coach message feel person cultural...    2024-01-03
# 3  Around pressure health play yard they federal ...    2024-01-04
#
#   Complaint Status  Resolution Time (Days)
# 1         Resolved                    21.0
# 2         Resolved                    11.0
# 3          Pending                    14.0

# %%
data.rename(columns={'Date Received': 'date'}, inplace=True)

# %%
data
# Out:
#   Complaint ID      Location Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description        date  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Resolution Time (Days)
# 1         Resolved                    21.0
# 2         Resolved                    11.0
# 3          Pending                    14.0

# %%
data.rename(columns={'date': 'Dates', 'Location': 'customers'}, inplace=True)

# %%
data
# Out:
#   Complaint ID     customers Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description       Dates  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Resolution Time (Days)
# 1         Resolved                    21.0
# 2         Resolved                    11.0
# 3          Pending                    14.0

# %%
data.rename(columns={'Dates': 'Age_Years', 'customers': 'City_Name', 'Resolution Time (Days)': 'Price'}, inplace=True)

# %%
data
# Out:
#   Complaint ID     City_Name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description   Age_Years  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Price
# 1         Resolved   21.0
# 2         Resolved   11.0
# 3          Pending   14.0

# %%
total_price = data['Price'].sum()
print("\nTotal sum of Price:", total_price)
# Out:
# Total sum of Price: 46.0

# %%
city_counts = data['Customer Name'].value_counts()
print("\nCount of each Customer Name:")
print(data)
# Out:
# Count of each Customer Name:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
age_sum_per_city = data.groupby('City_Name')['Age_Years'].sum()
print("\nTotal sum of Age_Years per City_Name:")
print(age_sum_per_city)
# Out:
# Total sum of Age_Years per City_Name:
# City_Name
# Calvin Bowen    2024-01-02
# Hunter King     2024-01-04
# Jared Reed      2024-01-03
# Name: Age_Years, dtype: object

# %%
max_age = data['Age_Years'].max()
print("\nHighest Age_Years in dataset:", max_age)
# Out:
# Highest Age_Years in dataset: 2024-01-04

# %%
min_price = data['Price'].min()
print("\nMinimum Price in dataset:", min_price)
# Out:
# Minimum Price in dataset: 11.0

# %%
plt.figure(figsize=(10, 5))
plt.plot(data.index, data['Age_Years'], marker='o', linestyle='-', color='blue')
plt.xlabel('Index')
plt.ylabel('Age_Years')
plt.title('Age over Index')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Age_Years'], bins=10, color='purple', edgecolor='black')
plt.xlabel('Age_Years')
plt.ylabel('Frequency')
plt.title('Histogram of Age_Years')
plt.show()

# %%
plt.figure(figsize=(10, 6))
data['City_Name'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140, cmap='Set3')
plt.ylabel('')
plt.title('City Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['Age_Years'], data['Price'], alpha=0.5, color='b')
plt.xlabel('Age_Years')
plt.ylabel('Price')
plt.title('Scatter Plot between Age_Years and Price')
plt.show()

# %%
data
# Out:
#   Complaint ID     City_Name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description   Age_Years  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Price
# 1         Resolved   21.0
# 2         Resolved   11.0
# 3          Pending   14.0

# %%
plt.figure(figsize=(6, 4))
data['Age_Years'].plot(kind='box')
plt.title('Box Plot of Age_Years')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age_Years'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 plt.figure(figsize=(6, 4))
# ...

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data
# Out:
#   Complaint ID     City_Name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description   Age_Years  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Price
# 1         Resolved   21.0
# 2         Resolved   11.0
# 3          Pending   14.0

# %%
data
# Out:
#   Complaint ID     City_Name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description   Age_Years  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Price
# 1         Resolved   21.0
# 2         Resolved   11.0
# 3          Pending   14.0

# %%
first_row = data.iloc[0]
print("\nFirst row of the dataset:")
print(first_row)
# Out:
# First row of the dataset:
# Complaint ID                                                       CMP1001
# City_Name                                                     Calvin Bowen
# Product/Service                                                    Telecom
# Complaint Description    Company just newspaper structure stand much li...
# Age_Years                                                       2024-01-02
# Complaint Status                                                  Resolved
# Price                                                                 21.0
# Name: 1, dtype: object

# %%
ast_three_rows = data.iloc[-3:]
print("\nLast 3 rows of the dataset:")
print(data)
# Out:
# Last 3 rows of the dataset:
#   Complaint ID     City_Name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description   Age_Years  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Price
# 1         Resolved   21.0
# 2         Resolved   11.0
# 3          Pending   14.0

# %%
first_five_rows_three_columns = data.iloc[:5, :3]
print("\nFirst 5 rows and first 3 columns:")
print(data)
# Out:
# First 5 rows and first 3 columns:
#   Complaint ID     City_Name Product/Service  \
# 1      CMP1001  Calvin Bowen         Telecom
# 2      CMP1002    Jared Reed          Retail
# 3      CMP1003   Hunter King         Banking
#
#                                Complaint Description   Age_Years  \
# 1  Company just newspaper structure stand much li...  2024-01-02
# 2  Should than coach message feel person cultural...  2024-01-03
# 3  Around pressure health play yard they federal ...  2024-01-04
#
#   Complaint Status  Price
# 1         Resolved   21.0
# 2         Resolved   11.0
# 3          Pending   14.0

# %%
data = data.iloc[:, 1:3]
print("\nAll rows with only the 2nd and 3rd columns:")
print(data)
# Out:
# All rows with only the 2nd and 3rd columns:
#       City_Name Product/Service
# 1  Calvin Bowen         Telecom
# 2    Jared Reed          Retail
# 3   Hunter King         Banking

# %%
data
# Out:
#                    mean  median
# Customer Name
# Alan Patel          1.0     1.0
# Amanda Pierce       NaN     NaN
# Amanda Walker      29.0    29.0
# Andrew Walters      NaN     NaN
# Ann Cox             NaN     NaN
# ...                 ...     ...
# Tiffany Martin     24.0    24.0
# Timothy Singleton   8.0     8.0
# Timothy Thornton    9.0     9.0
# Trevor Moyer       22.0    22.0
# Willie Powell      24.0    24.0
#
# [100 rows x 2 columns]

# %%
data['cus name'] = data['cus name'].replace('New York', 'NYC')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cus name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 data['cus name'] = data['cus name'].replace('New York', 'NYC')
#
# ...

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
numerical_column = 'Price'  # Update with the actual column name
data[numerical_column] = data[numerical_column].replace(0, np.nan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 numerical_column = 'Price'  # Update with the actual column name
# ...

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data.replace(100, 50, inplace=True)

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data['Complaint Status'] = data['Complaint Status'].replace({'Resolved': 1, 'Pending': 0})

# %%
data
# Out:
#       City_Name Product/Service
# 1  Calvin Bowen         Telecom
# 2    Jared Reed          Retail
# 3   Hunter King         Banking

# %%
data['Complaint Description	'] = data['Complaint Description'].replace({'High': 'Medium', 'Low': 'Small'})

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...

# %%
data
# Out:
#    Complaint ID      Customer Name Product/Service     Complaint Type  \
# 0       CMP1000            Ann Cox          Retail      Billing Issue
# 1       CMP1001       Calvin Bowen         Telecom       Poor Service
# 2       CMP1002         Jared Reed          Retail       Poor Service
# 3       CMP1003        Hunter King         Banking      Wrong Product
# 4       CMP1004     Deborah Martin         Banking       Poor Service
# ..          ...                ...             ...                ...
# 95      CMP1095      Blake Bennett      E-commerce  Delay in Response
# 96      CMP1096  Stephen Carpenter       Insurance      Billing Issue
# 97      CMP1097      David Burgess      E-commerce      Wrong Product
# 98      CMP1098        Savannah Yu         Telecom      Billing Issue
# 99      CMP1099      Joseph Morgan       Insurance      Wrong Product
#
#                                 Complaint Description Date Received  \
# ...
